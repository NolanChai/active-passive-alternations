# %%
import conllu
from conllu import Token, parse, parse_tree
from pyinflect import getAllInflections, getInflection
from src.utils import *
from src.units.word import *
from src.units.sentence import *

# %%
with open("data/en_gum-ud-train.conllu", "r") as f:
    text = f.read()
sentences = parse(text)

# %%
i = 100
token = sentences[i][4]
print(sentences[i].metadata['text'])
[w for w in sentences[i]]
# Out:
# The country’s unequal economic growth originated in the colonial era and reflects how the Spanish metropolis influenced the establishment of extractive institutions [7].
# [{'id': 1,
#   'form': 'The',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 2,
#   'deprel': 'det',
#   'deps': [('det', 2)],
#   'misc': {'Discourse': 'context-background:105->104:0:sem-synym-803-804,813-815-_',
#    'Entity': '(159-abstract-new-nnnnn-cf2-6-sgl(157-place-giv:act-sssss-cf1*-2-coref-Argentina',
#    'PDTB': 'Implicit:Expansion.Conjunction:and:_:801-812:813-839'}},
#  {'id': (2, '-', 3),
#   'form': 'country’s',
#   'lemma': '_',
#   'upos': '_',
#   'xpos': None,
#   'feats': None,
#   'head': None,
#   'deprel': '_',
#   'deps': None,
#   'misc': None},
#  {'id': 2,
#   'form': 'country',
#   'lemma': 'country',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nmod:poss',
#   'deps': [('nmod:poss', 6)],
#   'misc': None},
#  {'id': 3,
#   'form': '’s',
#   'lemma': "'s",
#   'upos': 'PART',
#   'xpos': 'POS',
#   'feats': None,
#   'head': 2,
#   'deprel': 'case',
#   'deps': [('case', 2)],
#   'misc': {'Entity': '157)'}},
#  {'id': 4,
#   'form': 'unequal',
#   'lemma': 'unequal',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': {'Degree': 'Pos'},
#   'head': 6,
#   'deprel': 'amod',
#   'deps': [('amod', 6)],
#   'misc': {'MSeg': 'un-equal', 'Negation': 'Yes'}},
#  {'id': 5,
#   'form': 'economic',
#   'lemma': 'economic',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': {'Degree': 'Pos'},
#   'head': 6,
#   'deprel': 'amod',
#   'deps': [('amod', 6)],
#   'misc': {'MSeg': 'econom-ic'}},
#  {'id': 6,
#   'form': 'growth',
#   'lemma': 'growth',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nsubj',
#   'deps': [('nsubj', 7), ('nsubj', 13)],
#   'misc': {'Entity': '159)', 'MSeg': 'grow-th'}},
#  {'id': 7,
#   'form': 'originated',
#   'lemma': 'originate',
#   'upos': 'VERB',
#   'xpos': 'VBD',
#   'feats': {'Mood': 'Ind',
#    'Number': 'Sing',
#    'Person': '3',
#    'Tense': 'Past',
#    'VerbForm': 'Fin'},
#   'head': 0,
#   'deprel': 'root',
#   'deps': [('root', 0)],
#   'misc': {'MSeg': 'origin-at-ed'}},
#  {'id': 8,
#   'form': 'in',
#   'lemma': 'in',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 11,
#   'deprel': 'case',
#   'deps': [('case', 11)],
#   'misc': None},
#  {'id': 9,
#   'form': 'the',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 11,
#   'deprel': 'det',
#   'deps': [('det', 11)],
#   'misc': {'Entity': '(160-time-new-nnnnn-cf5-3-sgl',
#    'XML': '<date from:::"1534" to:::"1814">'}},
#  {'id': 10,
#   'form': 'colonial',
#   'lemma': 'colonial',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': {'Degree': 'Pos'},
#   'head': 11,
#   'deprel': 'amod',
#   'deps': [('amod', 11)],
#   'misc': {'MSeg': 'coloni-al'}},
#  {'id': 11,
#   'form': 'era',
#   'lemma': 'era',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'obl',
#   'deps': [('obl:in', 7)],
#   'misc': {'Entity': '160)', 'XML': '</date>'}},
#  {'id': 12,
#   'form': 'and',
#   'lemma': 'and',
#   'upos': 'CCONJ',
#   'xpos': 'CC',
#   'feats': None,
#   'head': 13,
#   'deprel': 'cc',
#   'deps': [('cc', 13)],
#   'misc': {'Discourse': 'joint-list_m:106->105:0:dm-and-824-_',
#    'PDTB': 'Explicit:Expansion.Conjunction:and:824:813-823:825-835'}},
#  {'id': 13,
#   'form': 'reflects',
#   'lemma': 'reflect',
#   'upos': 'VERB',
#   'xpos': 'VBZ',
#   'feats': {'Mood': 'Ind',
#    'Number': 'Sing',
#    'Person': '3',
#    'Tense': 'Pres',
#    'VerbForm': 'Fin'},
#   'head': 7,
#   'deprel': 'conj',
#   'deps': [('conj:and', 7)],
#   'misc': {'MSeg': 'reflect-s'}},
#  {'id': 14,
#   'form': 'how',
#   'lemma': 'how',
#   'upos': 'ADV',
#   'xpos': 'WRB',
#   'feats': {'PronType': 'Rel'},
#   'head': 13,
#   'deprel': 'obj',
#   'deps': [('obj', 13)],
#   'misc': None},
#  {'id': 15,
#   'form': 'the',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 17,
#   'deprel': 'det',
#   'deps': [('det', 17)],
#   'misc': {'Entity': '(161-place-new-nnnnn-cf3-3-sgl'}},
#  {'id': 16,
#   'form': 'Spanish',
#   'lemma': 'Spanish',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': {'Degree': 'Pos'},
#   'head': 17,
#   'deprel': 'amod',
#   'deps': [('amod', 17)],
#   'misc': {'MSeg': 'Span-ish'}},
#  {'id': 17,
#   'form': 'metropolis',
#   'lemma': 'metropolis',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 18,
#   'deprel': 'nsubj',
#   'deps': [('nsubj', 18)],
#   'misc': {'Entity': '161)'}},
#  {'id': 18,
#   'form': 'influenced',
#   'lemma': 'influence',
#   'upos': 'VERB',
#   'xpos': 'VBD',
#   'feats': {'Mood': 'Ind',
#    'Number': 'Sing',
#    'Person': '3',
#    'Tense': 'Past',
#    'VerbForm': 'Fin'},
#   'head': 14,
#   'deprel': 'advcl:relcl',
#   'deps': [('advcl:relcl', 14)],
#   'misc': {'MSeg': 'influenc-ed'}},
#  {'id': 19,
#   'form': 'the',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 20,
#   'deprel': 'det',
#   'deps': [('det', 20)],
#   'misc': {'Entity': '(162-event-new-nnnnn-cf4-2-sgl'}},
#  {'id': 20,
#   'form': 'establishment',
#   'lemma': 'establishment',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 18,
#   'deprel': 'obj',
#   'deps': [('obj', 18)],
#   'misc': {'MSeg': 'establish-ment'}},
#  {'id': 21,
#   'form': 'of',
#   'lemma': 'of',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 23,
#   'deprel': 'case',
#   'deps': [('case', 23)],
#   'misc': None},
#  {'id': 22,
#   'form': 'extractive',
#   'lemma': 'extractive',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': {'Degree': 'Pos'},
#   'head': 23,
#   'deprel': 'amod',
#   'deps': [('amod', 23)],
#   'misc': {'Entity': '(163-organization-new-nnsns-cf6-2-sgl',
#    'MSeg': 'extract-ive'}},
#  {'id': 23,
#   'form': 'institutions',
#   'lemma': 'institution',
#   'upos': 'NOUN',
#   'xpos': 'NNS',
#   'feats': {'Number': 'Plur'},
#   'head': 20,
#   'deprel': 'nmod',
#   'deps': [('nmod:of', 20)],
#   'misc': {'Entity': '163)162)', 'MSeg': 'institut-ion-s'}},
#  {'id': 24,
#   'form': '[',
#   'lemma': '[',
#   'upos': 'PUNCT',
#   'xpos': '-LRB-',
#   'feats': None,
#   'head': 25,
#   'deprel': 'punct',
#   'deps': [('punct', 25)],
#   'misc': {'Discourse': 'explanation-evidence:107->105:1:grf-prn-836,838-_',
#    'SpaceAfter': 'No'}},
#  {'id': 25,
#   'form': '7',
#   'lemma': '7',
#   'upos': 'NUM',
#   'xpos': 'CD',
#   'feats': {'NumForm': 'Digit', 'NumType': 'Card'},
#   'head': 7,
#   'deprel': 'parataxis',
#   'deps': [('parataxis', 7)],
#   'misc': {'Entity': '(164-abstract-new-nnnnn-cf7-1-sgl)',
#    'SpaceAfter': 'No',
#    'XML': '<ref></ref>'}},
#  {'id': 26,
#   'form': ']',
#   'lemma': ']',
#   'upos': 'PUNCT',
#   'xpos': '-RRB-',
#   'feats': None,
#   'head': 25,
#   'deprel': 'punct',
#   'deps': [('punct', 25)],
#   'misc': {'SpaceAfter': 'No'}},
#  {'id': 27,
#   'form': '.',
#   'lemma': '.',
#   'upos': 'PUNCT',
#   'xpos': '.',
#   'feats': None,
#   'head': 7,
#   'deprel': 'punct',
#   'deps': [('punct', 7)],
#   'misc': None}]

# %%
new_sentences = []
for sent in sentences:
    s = Sentence(sent)
    new_sentences.append(s)

# %%
passive_sentences = [s for s in new_sentences if s.is_passive]

# %%
passive_sentences[0].text
# Out:
# 'The direction of saccades is determined by an interaction between the goals of the observer and the physical properties of the different elements of the scene (e.g. colour, texture, brightness etc).'

# %%
build_subtree(passive_sentences[0][1])
# Out:
# [{'id': 1,
#   'form': 'The',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 2,
#   'deprel': 'det',
#   'deps': [('det', 2)],
#   'misc': {'Discourse': 'elaboration-additional:39->36:2:sem-synym-369-370,380-386,391,401-402-_',
#    'Entity': '(95-abstract-new-nnnnn-cf7-2-sgl',
#    'PDTB': 'Implicit:Expansion.Level-of-detail.Arg2-as-detail:in particular:_:364-387:388-423'},
#   'inflection': 'DT',
#   'children': []},
#  {'id': 2,
#   'form': 'direction',
#   'lemma': 'direction',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nsubj:pass',
#   'deps': [('nsubj:pass', 6)],
#   'misc': {'MSeg': 'direct-ion'},
#   'inflection': 'NN',
#   'children': [{'id': 1,
#     'form': 'The',
#     'lemma': 'the',
#     'upos': 'DET',
#     'xpos': 'DT',
#     'feats': {'Definite': 'Def', 'PronType': 'Art'},
#     'head': 2,
#     'deprel': 'det',
#     'deps': [('det', 2)],
#     'misc': {'Discourse': 'elaboration-additional:39->36:2:sem-synym-369-370,380-386,391,401-402-_',
#      'Entity': '(95-abstract-new-nnnnn-cf7-2-sgl',
#      'PDTB': 'Implicit:Expansion.Level-of-detail.Arg2-as-detail:in particular:_:364-387:388-423'},
#     'inflection': 'DT',
#     'children': []},
#    {'id': 4,
#     'form': 'saccades',
#     'lemma': 'saccade',
#     'upos': 'NOUN',
#     'xpos': 'NNS',
#     'feats': {'Number': 'Plur'},
#     'head': 2,
#     'deprel': 'nmod',
#     'deps': [('nmod:of', 2)],
#     'misc': {'Entity': '(93-event-giv:act-nnnnn-cf2-1-coref)95)',
#      'MSeg': 'saccade-s'},
#     'inflection': 'NNS',
#     'children': [{'id': 3,
#       'form': 'of',
#       'lemma': 'of',
#       'upos': 'ADP',
#       'xpos': 'IN',
#       'feats': None,
#       'head': 4,
#       'deprel': 'case',
#       'deps': [('case', 4)],
#       'misc': None,
#       'inflection': 'IN',
#       'children': []}]}]},
#  {'id': 3,
#   'form': 'of',
#   'lemma': 'of',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 4,
#   'deprel': 'case',
#   'deps': [('case', 4)],
#   'misc': None,
#   'inflection': 'IN',
#   'children': []},
#  {'id': 4,
#   'form': 'saccades',
#   'lemma': 'saccade',
#   'upos': 'NOUN',
#   'xpos': 'NNS',
#   'feats': {'Number': 'Plur'},
#   'head': 2,
#   'deprel': 'nmod',
#   'deps': [('nmod:of', 2)],
#   'misc': {'Entity': '(93-event-giv:act-nnnnn-cf2-1-coref)95)',
#    'MSeg': 'saccade-s'},
#   'inflection': 'NNS',
#   'children': [{'id': 3,
#     'form': 'of',
#     'lemma': 'of',
#     'upos': 'ADP',
#     'xpos': 'IN',
#     'feats': None,
#     'head': 4,
#     'deprel': 'case',
#     'deps': [('case', 4)],
#     'misc': None,
#     'inflection': 'IN',
#     'children': []}]}]

# %%
passive_sentences_test = []
for i, sent in enumerate(passive_sentences):
    print(i)
    print(sent.text)
    try:
        new_sent = PassiveSentence(sent)
        passive_sentences_test.append(new_sent)
        print(f'{new_sent.passive_subject.text} | {new_sent.verb.text} | {new_sent.agent.text}')
        active_sent = new_sent.depassivize()
        print(active_sent.text)
    except Exception as e:
        print("Failed:", sent.text)
        print("Error:", e, type(e))
    print()
# Out:
# 0
# The direction of saccades is determined by an interaction between the goals of the observer and the physical properties of the different elements of the scene (e.g. colour, texture, brightness etc).
# The direction of saccades | is determined | by an interaction between the goals of the observer and the physical properties of the different elements of the scene ( e.g. colour , texture , brightness etc )
# an interaction between the goals of the observer and the physical properties of the different elements of the scene ( e.g. colour , texture , brightness etc ) determines The direction of saccades .
#
# 1
# For example, differences in recruitment and retention strategies across departments will be washed out by averaging, thereby masking any insights into the efficacy of individual strategies and policies.
# differences in recruitment and retention strategies across departments | will be washed | by averaging
# For example , averaging will washed differences in recruitment and retention strategies across departments out , thereby masking any insights into the efficacy of individual strategies and policies .
#
# 2
# In other words, it is critical that economic agents believe that their property rights will not be taken away by other public or private actors [15].
# their property rights | will be taken | by other public or private actors
# In other words , it is critical that economic agents believe that other public or private actors will taken their property rights away [ 15 ] .
#
# 3
# If the decisions taken by the state are not based on the general interest and, in their execution, do not respect property rights, the number of transactions will be reduced, which will result in unfavorable economic performance.
# Failed: If the decisions taken by the state are not based on the general interest and, in their execution, do not respect property rights, the number of transactions will be reduced, which will result in unfavorable economic performance.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 4
# Then, our corpus and system are described, followed by an evaluation of the system.
# Failed: Then, our corpus and system are described, followed by an evaluation of the system.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 5
# Besides the enjambment types above, Spang (1983) noted that if a subject or direct object and their related verbs occur in two different lines of poetry, this can also feel unusual for a reader, even if the effect is less pronounced than in the environments identified by Quilis.
# Failed: Besides the enjambment types above, Spang (1983) noted that if a subject or direct object and their related verbs occur in two different lines of poetry, this can also feel unusual for a reader, even if the effect is less pronounced than in the environments identified by Quilis.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 6
# His typology is still considered current, and was adopted by later authors, although complementary enjambment typologies have been proposed, as Martínez Cantón (2011) reviews.
# Failed: His typology is still considered current, and was adopted by later authors, although complementary enjambment typologies have been proposed, as Martínez Cantón (2011) reviews.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 7
# We live in an epistemic environment that is heavily and deliberately polluted by agents who use mimicry and other methods as a means of inflating their pretense to expertise.
# that | is heavily deliberately polluted | by agents who use mimicry and other methods as a means of inflating their pretense to expertise
# We live in an epistemic environment agents who use mimicry and other methods as a means of inflating their pretense to expertise heavily deliberately polluted that .
#
# 8
# Thus, the sound of the word dog in English is connected to the concept ‘dog’ by historical accident and not by any natural connection; roughly the same concept is just as well denoted in French by chien, in German by hund, and in Japanese by inu.
# the sound of the word dog in English | Thus is connected | ’ by historical accident and not by any natural connection
# Thus , ’ historical accident and not by any natural connection Thus connected the sound of the word dog in English to the concept ‘ dog ; roughly the same concept is just as well denoted in French by chien , denoted in German by hund , and denoted in Japanese by inu .
#
# 9
# We observe that this item fulfils a crucial need shared by all languages – the efficient signalling of problems of hearing and understanding – and we propose that its form is constrained by selective pressures in a conversational environment that is essentially the same in all languages.
# its form | is constrained | by selective pressures in a conversational environment that is essentially the same in all languages
# We observe that this item fulfils a crucial need shared by all languages – the efficient signalling of problems of hearing and understanding – and we propose that selective pressures in a conversational environment that is essentially the same in all languages constrain its form .
#
# 10
# This is followed by a repetition of the original statement by G.
# This | is followed | by a repetition of the original statement by G
# a repetition of the original statement by G follows This .
#
# 11
# repair is initiated not by the speaker of the first turn but by the other participant (“other-initiated”), and the repair initiator signals that there is a problem, but it leaves open what the problem is (“open”) [11].
# repair | is initiated | not by the speaker of the first turn but by the other participant ( “ other - initiated ” )
# not the speaker of the first turn but by the other participant ( “ other - initiated ” ) initiates repair , and the repair initiator signals that there is a problem , but it leaves open what the problem is ( “ open ” ) [ 11 ] .
#
# 12
# Skin aging and skin cancer will be discussed as those reactions produced by prolonged or repeated UVR exposure [4].
# Failed: Skin aging and skin cancer will be discussed as those reactions produced by prolonged or repeated UVR exposure [4].
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 13
# In response to the aforementioned situation where the three types of lights are compared by their efficiency and effectiveness as light sources, the proponents conducted this study.
# the three types of lights | where are compared | by their efficiency and effectiveness as light sources
# In response to the aforementioned situation where their efficiency and effectiveness as light sources where compared the three types of lights , the proponents conducted this study .
#
# 14
# The different mutants are generated automatically by the application of mutation operators.
# The different mutants | are generated | by the application of mutation operators
# the application of mutation operators generates The different mutants automatically .
#
# 15
# A Geofence is determined by a geographical location expressed in terms of latitude, longitude, and a radius around that location.
# A Geofence | is determined | by a geographical location expressed in terms of latitude , longitude , and a radius around that location
# a geographical location expressed in terms of latitude , longitude , and a radius around that location determines A Geofence .
#
# 16
# Replication studies are considered by many to play a fundamental role in any scientific endeavor.
# Replication studies | are considered | by many
# many consider Replication studies to play a fundamental role in any scientific endeavor .
#
# 17
# The research questions and methods of the systematic review were largely determined by the narrative review but also emerged through the design and piloting of the coding instrument.
# The research questions and methods of the systematic review | were largely determined | by the narrative review
# the narrative review largely determined The research questions and methods of the systematic review but also emerged through the design and piloting of the coding instrument .
#
# 18
# Based on many experiments, the L-band is evidenced as the optimal frequency for remote sensing of SSS, which has been adopted by SMOS, Aquarius/SAC-D and SMAP.
# Failed: Based on many experiments, the L-band is evidenced as the optimal frequency for remote sensing of SSS, which has been adopted by SMOS, Aquarius/SAC-D and SMAP.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 19
# Among these models, the small-slope approximation/small perturbation model (SSA / SPM) [18,19,20,21], two scale model (TSM) [22,23,24] and empirical/semi-empirical models [25,26] have been widely used by the research community and implemented in different satellite data processing systems.
# the small - slope approximation / small perturbation model ( SSA / SPM ) [ 18 , 19 , 20 , 21 ] , two scale model ( TSM ) [ 22 , 23 , 24 ] and empirical / semi-empirical models [ 25 , 26 ] | have been widely used | by the research community
# Among these models , the research community had widely used the small - slope approximation / small perturbation model ( SSA / SPM ) [ 18 , 19 , 20 , 21 ] , two scale model ( TSM ) [ 22 , 23 , 24 ] and empirical / semi-empirical models [ 25 , 26 ] and implemented in different satellite data processing systems .
#
# 20
# As the foam effect is significant at high wind speed conditions (above a threshold of 12 m/s) due to strong wave breaking, it has been corrected by numerous models; for example, the semi-empirical models [27,28] and radiative transfer equation (RTE) based models [29,30], which were developed to estimate the foam covered sea surface emissivity.
# it | has been corrected | by numerous models
# As the foam effect is significant at high wind speed conditions ( above a threshold of 12 m / s ) due to strong wave breaking , numerous models have corrected it ; for example , the semi-empirical models [ 27 , 28 ] and radiative transfer equation ( RTE ) based models [ 29 , 30 ] , which were developed to estimate the foam covered sea surface emissivity .
#
# 21
# Furthermore, the satellite measurements of SSS are hampered by the effect of radio frequency interference (RFI) in offshore areas of China (i.e., Bohai sea, Yellow sea and East China sea), which causes a large amount of data to be discarded [33].
# the satellite measurements of SSS | Furthermore are hampered | by the effect of radio frequency interference ( RFI ) in offshore areas of China ( i.e. , Bohai sea , Yellow sea and East China sea ) , which causes a large amount of data to be discarded
# Furthermore , the effect of radio frequency interference ( RFI ) in offshore areas of China ( i.e. , Bohai sea , Yellow sea and East China sea ) , which causes a large amount of data to be discarded Furthermore hampered the satellite measurements of SSS [ 33 ] .
#
# 22
# Our data show that for a given CFL mass, femoral retraction can be greatly affected by the location of the CoM and limb postures.
# femoral retraction | can be greatly affected | by the location of the CoM and limb postures
# Our data show that for a given CFL mass , the location of the CoM and limb postures can greatly affected femoral retraction .
#
# 23
# One caveat, however, is that our approach uses tail reduction as the mechanism for CoM displacement despite it has been recently shown that the evolutionary change in CoM position was driven instead by forelimb enlargement [8].
# the evolutionary change in CoM position | was driven | by forelimb enlargement
# One caveat , however , is that our approach uses tail reduction as the mechanism for CoM displacement despite it has been recently shown that forelimb enlargement drove the evolutionary change in CoM position instead [ 8 ] .
#
# 24
# Readers of the book series had long anticipated and dreaded the events of the “Red Wedding”, while fans of the show unfamiliar with Martin’s narrative were largely taken unawares by the pivotal episode.
# fans of the show unfamiliar with Martin ’s narrative | were largely taken | by the pivotal episode
# Readers of the book series had long anticipated and dreaded the events of the “ Red Wedding ” , while the pivotal episode largely taken fans of the show unfamiliar with Martin ’s narrative unawares .
#
# 25
# one comment thread where fans were expected to be shocked by the outcome of the episode and one comment thread where fans had hotly anticipated it.
# Failed: one comment thread where fans were expected to be shocked by the outcome of the episode and one comment thread where fans had hotly anticipated it.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 26
# The question posed by this research is, fundamentally, an examination of how the problem of “access” is framed in postdigital society from the perspective of the consumer.
# Failed: The question posed by this research is, fundamentally, an examination of how the problem of “access” is framed in postdigital society from the perspective of the consumer.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 27
# Daniel Bernoulli was described by W. W. Rouse Ball as "by far the ablest of the younger Bernoullis".
# Daniel Bernoulli | was described | by W. W. Rouse Ball
# W. W. Rouse Ball described Daniel Bernoulli as " by far the ablest of the younger Bernoullis " .
#
# 28
# This was followed by a memoir on the theory of the tides, to which, conjointly with the memoirs by Euler and Colin Maclaurin, a prize was awarded by the French Academy: these three memoirs contain all that was done on this subject between the publication of Isaac Newton's Philosophiae Naturalis Principia Mathematica and the investigations of Pierre-Simon Laplace.
# This | was followed | by a memoir on the theory of the tides , to which , conjointly with the memoirs by Euler and Colin Maclaurin , a prize was awarded by the French Academy
# a memoir on the theory of the tides , to which , conjointly with the memoirs by Euler and Colin Maclaurin , a prize was awarded by the French Academy followed This : these three memoirs contain all that was done on this subject between the publication of Isaac Newton 's Philosophiae Naturalis Principia Mathematica and the investigations of Pierre - Simon Laplace .
#
# 29
# This is exploited by the wing of an aeroplane which is designed to create an area above its surface where the air velocity increases.
# This | is exploited | by the wing of an aeroplane which is designed to create an area above its surface where the air velocity increases
# the wing of an aeroplane which is designed to create an area above its surface where the air velocity increases exploits This .
#
# 30
# The pressure in this area is lower than that under the wing, so the wing is pushed upwards by the relatively higher pressure under the wing.
# the wing | so is pushed | by the relatively higher pressure under the wing
# The pressure in this area is lower than that under the wing , so the relatively higher pressure under the wing so pushed the wing upwards .
#
# 31
# Late in his life, he was invited by Deng Xiaoping to return to China in 1981.
# he | Late was invited | by Deng Xiaoping
# Late in his life , Deng Xiaoping Late invited him to return to China in 1981 .
#
# 32
# L'Enfant was recruited by Pierre Augustin Caron de Beaumarchais to serve in the American Revolutionary War in the United States.
# L'Enfant | was recruited | by Pierre Augustin Caron de Beaumarchais
# Pierre Augustin Caron de Beaumarchais recruited L'Enfant to serve in the American Revolutionary War in the United States .
#
# 33
# L'Enfant was promoted by brevet to Major in the Corps of Engineers on May 2, 1783, in recognition of his service to the cause of American liberty.
# L'Enfant | was promoted | by brevet
# brevet promoted L'Enfant to Major in the Corps of Engineers on May 2 , 1783 , in recognition of his service to the cause of American liberty .
#
# 34
# In 1968, he published his theory of Case Grammar (Fillmore 1968), which highlighted the fact that syntactic structure can be predicted by semantic participants.
# syntactic structure | can be predicted | by semantic participants
# In 1968 , he published his theory of Case Grammar ( Fillmore 1968 ) , which highlighted the fact that semantic participants can predicted syntactic structure .
#
# 35
# Over time, construction grammar developed into a research area of its own, and a number of variants have been proposed over the years by different researchers.
# a number of variants | have been proposed | by different researchers
# Over time , construction grammar developed into a research area of its own , and different researchers have proposed a number of variants over the years .
#
# 36
# Data is gathered from the British National Corpus, annotated for semantic and syntactic relations, and stored in a database organized by both lexical items and Frames.
# Failed: Data is gathered from the British National Corpus, annotated for semantic and syntactic relations, and stored in a database organized by both lexical items and Frames.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 37
# This conjecture is also supported by other letters Galois later wrote to his friends the night before he died.
# This conjecture | is also supported | by other letters Galois later wrote to his friends the night before he died
# other letters Galois later wrote to his friends the night before he died also supported This conjecture .
#
# 38
# Much more detailed speculation based on these scant historical details has been interpolated by many of Galois' biographers (most notably by Eric Temple Bell in Men of Mathematics), such as the frequently repeated speculation that the entire incident was stage-managed by the police and royalist factions to eliminate a political enemy. [14]
# Much more detailed speculation based on these scant historical details , such as the frequently repeated speculation that the entire incident was stage - managed by the police and royalist factions to eliminate a political enemy | has been interpolated | by many of Galois ' biographers
# many of Galois ' biographers had interpolated Much more detailed speculation based on these scant historical details , such as the frequently repeated speculation that the entire incident was stage - managed by the police and royalist factions to eliminate a political enemy ( most notably interpolated by Eric Temple Bell in Men of Mathematics ) , such as the frequently repeated speculation that the entire incident was stage - managed by the police and royalist factions to eliminate a political enemy . [ 14 ]
#
# 39
# On the other hand, extant newspaper clippings from only a few days after the duel give a description of his opponent (identified by the initials "L. D.") that appear to more accurately apply to one of Galois' Republican friends, most probably Ernest Duchatelet, who was imprisoned with Galois on the same charges. [21]
# Failed: On the other hand, extant newspaper clippings from only a few days after the duel give a description of his opponent (identified by the initials "L. D.") that appear to more accurately apply to one of Galois' Republican friends, most probably Ernest Duchatelet, who was imprisoned with Galois on the same charges. [21]
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 40
# Early in the morning of 30 May 1832, he was shot in the abdomen, [17] abandoned by his opponents and seconds, and was found by a passing farmer.
# Failed: Early in the morning of 30 May 1832, he was shot in the abdomen, [17] abandoned by his opponents and seconds, and was found by a passing farmer.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 41
# Goode was educated at Exeter School, an independent school in Exeter, Devon, [4] followed by the University of Birmingham and London's Webber Douglas Academy of Dramatic Art.
# Failed: Goode was educated at Exeter School, an independent school in Exeter, Devon, [4] followed by the University of Birmingham and London's Webber Douglas Academy of Dramatic Art.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 42
# An incomplete and faulty German translation, edited by Dr Moritz Posselt (Tagebuch des Generals Patrick Gordon) was published, the first volume at Moscow in 1849, the second at St Petersburg in 1851, and the third at St Petersburg in 1853; and Passages from the Diary of General Patrick Gordon of Auchleuchries (1635 – 1699), was printed, under the editorship of Joseph Robertson, for the Spalding Club, at Aberdeen, Scotland, 1859.
# Failed: An incomplete and faulty German translation, edited by Dr Moritz Posselt (Tagebuch des Generals Patrick Gordon) was published, the first volume at Moscow in 1849, the second at St Petersburg in 1851, and the third at St Petersburg in 1853; and Passages from the Diary of General Patrick Gordon of Auchleuchries (1635 – 1699), was printed, under the editorship of Joseph Robertson, for the Spalding Club, at Aberdeen, Scotland, 1859.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 43
# A new full scholarly edition of Gordon's Diary in English was published by the Centre for Irish and Scottish Studies in Aberdeen (6 vols, 2009 - 2016), as well as its translation into Russian.
# A new full scholarly edition of Gordon 's Diary in English , as well as its translation into Russian | was published | by the Centre for Irish and Scottish Studies in Aberdeen
# the Centre for Irish and Scottish Studies in Aberdeen published A new full scholarly edition of Gordon 's Diary in English , as well as its translation into Russian ( 6 vols , 2009 - 2016 ) , as well as its translation into Russian .
#
# 44
# In 2012, she was made a Dame by Elizabeth II for services to architecture, and in 2015 she became the first and only woman to be awarded the Royal Gold Medal from the Royal Institute of British Architects.
# she | was made | by Elizabeth II
# In 2012 , Elizabeth II made her a Dame for services to architecture , and in 2015 she became the first and only woman to be awarded the Royal Gold Medal from the Royal Institute of British Architects .
#
# 45
# She was described by The Guardian of London as the 'Queen of the curve', who "liberated architectural geometry, giving it a whole new expressive identity."
# She | was described | by The Guardian of London
# The Guardian of London described her as the ' Queen of the curve ' , who " liberated architectural geometry , giving it a whole new expressive identity . "
#
# 46
# She wrote relatively little as a result of living a brief life — she died at 24 — but her stories had a large impact on Japanese literature and she is still appreciated by the Japanese public today.
# she | is still appreciated | by the Japanese public
# She wrote relatively little as a result of living a brief life — she died at 24 — but her stories had a large impact on Japanese literature and the Japanese public still appreciated her today .
#
# 47
# The plots were thin, there was little development of character and they were loaded down by excessive sentiment, especially when compared to what she was writing concurrently in her diary.
# they | were loaded | by excessive sentiment
# The plots were thin , there was little development of character and excessive sentiment loaded them down , especially when compared to what she was writing concurrently in her diary .
#
# 48
# The stories of her mature period (1894 – 96) were not only marked by her experience living near the red-light district and greater concern over the plight of women, but also by the influence of Ihara Saikaku, a 17th-century writer, whose stories she had recently discovered.
# The stories of her mature period ( 1894 – 96 ) | were only marked | by her experience living near the red - light district and greater concern over the plight of women , but also by the influence of Ihara Saikaku , a 17th - century writer , whose stories she had recently discovered
# her experience living near the red - light district and greater concern over the plight of women , but also by the influence of Ihara Saikaku , a 17th - century writer , whose stories she had recently discovered only marked The stories of her mature period ( 1894 – 96 ) .
#
# 49
# In her humble home she was visited by other writers, students of poetry, admirers, the curious, critics, and editors requesting her collaboration.
# she | was visited | by other writers , students of poetry , admirers , the curious , critics , and editors requesting her collaboration
# In her humble home other writers , students of poetry , admirers , the curious , critics , and editors requesting her collaboration visited her .
#
# 50
# Holt was drafted by the Pittsburgh Pirates with the club's ninth round selection in the 2009 Major League Baseball Draft, one pick before his Rice teammate Ryan Berry. [7]
# Holt | was drafted | by the Pittsburgh Pirates
# the Pittsburgh Pirates drafted Holt with the club 's ninth round selection in the 2009 Major League Baseball Draft , one pick before his Rice teammate Ryan Berry . [ 7 ]
#
# 51
# Jerome is recognised as a saint and Doctor of the Church by the Catholic Church, the Eastern Orthodox Church, the Lutheran Church, and the Anglican Communion. [8]
# Jerome | is recognised | by the Catholic Church , the Eastern Orthodox Church , the Lutheran Church , and the Anglican Communion
# the Catholic Church , the Eastern Orthodox Church , the Lutheran Church , and the Anglican Communion recognises Jerome as a saint and Doctor of the Church . [ 8 ]
#
# 52
# Elevator to the Gallows (1958) with first-time director Louis Malle was followed by Malle's The Lovers (Les Amants, 1959). [7]
# Elevator to the Gallows ( 1958 ) with first - time director Louis Malle | was followed | by Malle 's The Lovers ( Les Amants , 1959 )
# Malle 's The Lovers ( Les Amants , 1959 ) followed Elevator to the Gallows ( 1958 ) with first - time director Louis Malle . [ 7 ]
#
# 53
# He was welcomed by Pachomius upon his arrival, and quickly integrated into the community at Tabennese around 328.
# He | was welcomed | by Pachomius
# Pachomius welcomed him upon his arrival , and quickly integrated into the community at Tabennese around 328 .
#
# 54
# Um, Jesus turned to his disciples, you remember, when some deserted him, and seemed, because they were disappointed in some of his sayings, and they were offended by some of the things he said, and they walked no longer with him it said.
# Failed: Um, Jesus turned to his disciples, you remember, when some deserted him, and seemed, because they were disappointed in some of his sayings, and they were offended by some of the things he said, and they walked no longer with him it said.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 55
# On the other hand, we have passages of Scripture, which seem to indicate, that the will is not free, and that the –, and that man i- th- is – man is predestined by a an omnipotent sovereign will of God.
# man man | is predestined | by a an omnipotent sovereign will of God
# On the other hand , we have passages of Scripture , which seem to indicate , that the will is not free , and that the – , and that a an omnipotent sovereign will of God predestines man man .
#
# 56
# Uh I was called by Matthew here, to do the job for him.
# I | was called | by Matthew here
# Uh Matthew here called me , to do the job for him .
#
# 57
# And it's our position that those specific procedures are the ones that are required by due process and not a Chapter 91 contested case here.
# that | are required | by due process and not a Chapter 91 contested case here
# And it 's our position that those specific procedures are the ones due process and not a Chapter 91 contested case here requires that .
#
# 58
# We know that our readers are distracted and sometimes even overwhelmed by the myriad distractions that lie one click away on the Internet, but of course writers face the same glorious problem: the delirious world of information and communication and community that lurks behind your screen, one alt-tab away from your word-processor.
# our readers | are distracted | by the myriad distractions that lie one click away on the Internet
# We know that the myriad distractions that lie one click away on the Internet distract our readers and sometimes even overwhelmed , but of course writers face the same glorious problem : the delirious world of information and communication and community that lurks behind your screen , one alt - tab away from your word - processor .
#
# 59
# By all means, schedule a chat — voice, text, or video — when it’s needed, but leaving your IM running is like sitting down to work after hanging a giant “DISTRACT ME” sign over your desk, one that shines brightly enough to be seen by the entire world.
# Failed: By all means, schedule a chat — voice, text, or video — when it’s needed, but leaving your IM running is like sitting down to work after hanging a giant “DISTRACT ME” sign over your desk, one that shines brightly enough to be seen by the entire world.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 60
# The notion has been advanced by liberals such as James Tobin, John Kenneth Galbraith, and George McGovern, and by conservatives like Friedrich Hayek, Milton Friedman, and Richard Nixon.
# The notion | has been advanced | by liberals such as James Tobin , John Kenneth Galbraith , and George McGovern , and by conservatives like Friedrich Hayek , Milton Friedman , and Richard Nixon
# liberals such as James Tobin , John Kenneth Galbraith , and George McGovern , and by conservatives like Friedrich Hayek , Milton Friedman , and Richard Nixon have advanced The notion .
#
# 61
# This value isn’t created by single individuals or corporations; it’s created collectively and hence belongs equally to all.
# This value | is created | by single individuals or corporations
# single individuals or corporations create This value ; it ’s created collectively and hence belongs equally to all .
#
# 62
# Frozen foods have long been marginalized by foodies as pale, second-rate substitutes for their fresh equivalents, but those sentiments are starting to shift.
# Frozen foods | have long been marginalized | by foodies
# foodies have long marginalized Frozen foods as pale , second - rate substitutes for their fresh equivalents , but those sentiments are starting to shift .
#
# 63
# Throughout Ghost, Major Kusanagi is plagued by doubts of who she is.
# Major Kusanagi | is plagued | by doubts of who she is
# Throughout Ghost , doubts of who she is plague Major Kusanagi .
#
# 64
# For many years after her death, however, Tyler was tortured by the memory of a certain visit from her.
# Tyler | however was tortured | by the memory of a certain visit from her
# For many years after her death , however , the memory of a certain visit from her however tortured Tyler .
#
# 65
# Water burst over the barrels and cans standing under the eaves and gutters, flooding the pathways, carrying away all that wasn’t fixed solid and licking at the stairs to the back porch before climbing each step and lapping against the planks we were sitting on, a wooden raft surrounded by angry water and martial beat drum, drum, drumming on the roof above.
# Failed: Water burst over the barrels and cans standing under the eaves and gutters, flooding the pathways, carrying away all that wasn’t fixed solid and licking at the stairs to the back porch before climbing each step and lapping against the planks we were sitting on, a wooden raft surrounded by angry water and martial beat drum, drum, drumming on the roof above.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 66
# Jenna was in the tub, and I was doing the Times crossword, listening to the clang of the radiators and the swish of the taxis on the slush outside, when my coffee-scented reverie was broken by a loud squawk from the bathroom, and a splash, and a flesh-upon-cold-tile sort of thump.
# my coffee - scented reverie | when was broken | by a loud squawk from the bathroom , and a splash , and a flesh - upon - cold - tile sort of thump
# Jenna was in the tub , and I was doing the Times crossword , listening to the clang of the radiators and the swish of the taxis on the slush outside , when a loud squawk from the bathroom , and a splash , and a flesh - upon - cold - tile sort of thump when broken my coffee - scented reverie .
#
# 67
# She’d be irritated by her own wet footprints on the battered wood of the hallway floor later, but right now she had blood on her mind.
# She | ’d be irritated | by her own wet footprints on the battered wood of the hallway floor
# her own wet footprints on the battered wood of the hallway floor would irritated her later , but right now she had blood on her mind .
#
# 68
# Once it got started, I realised that the idea must have been inspired by the title of Justine Larbalestier’s How to Ditch Your Fairy, although it has nothing at all to do with that story at all.
# Failed: Once it got started, I realised that the idea must have been inspired by the title of Justine Larbalestier’s How to Ditch Your Fairy, although it has nothing at all to do with that story at all.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 69
# I dreamed that I was at the offworlder's home, where it was summer but no one was taking care of the stabros, and they were all glad, and so I was a hero - and I was startled awake by gunfire.
# I | was startled | by gunfire
# I dreamed that I was at the offworlder 's home , where it was summer but no one was taking care of the stabros , and they were all glad , and so I was a hero - and gunfire startled me awake .
#
# 70
# The beverage was inspired by the santorum neologism coined in advice columnist Dan Savage's column Savage Love in response to comments made by former Pennsylvania Senator Rick Santorum about homosexuality;
# The beverage | was inspired | by the santorum neologism coined in advice columnist Dan Savage 's column Savage Love in response to comments made by former Pennsylvania Senator Rick Santorum about homosexuality
# the santorum neologism coined in advice columnist Dan Savage 's column Savage Love in response to comments made by former Pennsylvania Senator Rick Santorum about homosexuality inspired The beverage ;
#
# 71
# The Pacific Standard bar is located in Brooklyn, New York, and is co-owned by Jonathan M. Stan and John-Christian G. Rauschenberg.
# Failed: The Pacific Standard bar is located in Brooklyn, New York, and is co-owned by Jonathan M. Stan and John-Christian G. Rauschenberg.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 72
# Rick Santorum himself has acknowledged and discussed the existence and prevalence of the santorum neologism phenomenon; he was quoted by The Canadian Press on his assessment of Google's response;
# he | was quoted | by The Canadian Press
# Rick Santorum himself has acknowledged and discussed the existence and prevalence of the santorum neologism phenomenon ; The Canadian Press quoted him on his assessment of Google 's response ;
#
# 73
# What sort of difficulties were posed by the unorthodox preservatives used, and what additional work might be possible on a specimen with intact DNA?
# What sort of difficulties | were posed | by the unorthodox preservatives used
# the unorthodox preservatives used posed What sort of difficulties , and what additional work might be possible on a specimen with intact DNA ?
#
# 74
# Jack Herrick, wikiHow founder interviewed by Wikinews
# Jack Herrick , wikiHow founder | interviewed | by Wikinews
# Failed: Jack Herrick, wikiHow founder interviewed by Wikinews
# Error: No auxiliary passive verb found. <class 'ValueError'>
#
# 75
# She was staggered by the loss last year to the Cardinals.
# She | was staggered | by the loss last year to the Cardinals
# the loss last year to the Cardinals staggered her .
#
# 76
# Moments like that must make you realize you have touched people who aren't normally touched by poetry.
# who | are normally touched | by poetry
# Moments like that must make you realize you have touched people poetry normally touched who .
#
# 77
# The minute the land was replaced by science, what is there to fight about?
# the land | was replaced | by science
# The minute science replaced the land , what is there to fight about ?
#
# 78
# He was interviewed by Wikinews.
# He | was interviewed | by Wikinews
# Wikinews interviewed him .
#
# 79
# I'm a little bit inspired by dreams but when eventually I started to write more seriously I was more interested in structure which also .. a bit like mathematics in a way .. for example my first book is called Opus 1 .. a collection of four long stories with musical structures.
# I | 'm inspired | by dreams
# dreams inspire me but when eventually I started to write more seriously I was more interested in structure which also .. a bit like mathematics in a way .. for example my first book is called Opus 1 .. a collection of four long stories with musical structures .
#
# 80
# Markus Landgraf has estimated the number of interstellar dust particles that should have been captured by Stardust during two periods of the "cruise" phase of the interplanetary orbit in which the spacecraft was moving with this wind.
# that | should have been captured | by Stardust
# Failed: Markus Landgraf has estimated the number of interstellar dust particles that should have been captured by Stardust during two periods of the "cruise" phase of the interplanetary orbit in which the spacecraft was moving with this wind.
# Error: 'NoneType' object is not subscriptable <class 'TypeError'>
#
# 81
# Under the present law all public facilities except recreation areas will be restored by the Federal Government.
# all public facilities except recreation areas | will be restored | by the Federal Government
# Under the present law the Federal Government will restored all public facilities except recreation areas .
#
# 82
# This risk aversion is sidestepped by allowing future rental payments to be determined by future conditions.
# Failed: This risk aversion is sidestepped by allowing future rental payments to be determined by future conditions.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 83
# Finally, the future rent of land can more justly be claimed by future generations than by today's citizens.
# the future rent of land | Finally can more justly be claimed | by future generations
# Finally , future generations Finally can more justly claimed the future rent of land than by today 's citizens .
#
# 84
# Then around November Ruth had to move to a single because of bad grades- that's one thing about this room, it can really hurt your grades - she moved upstairs to the 3rd floor, where there are 3 singles so the four-room became a 3 room for a while, until January, when the 3rd floor was condemned by some shitty building inspector.
# the 3rd floor | when was condemned | by some shitty building inspector
# Then around November Ruth had to move to a single because of bad grades - that 's one thing about this room , it can really hurt your grades - she moved upstairs to the 3rd floor , where there are 3 singles so the four - room became a 3 room for a while , until January , when some shitty building inspector when condemned the 3rd floor .
#
# 85
# THE ONLY DANGER ABOUT AFTER LIGHTS STUDYING IS BEING REPORTED BY THE VICTOR OR PINKERTON GUARDS WHO PATROL THE CAMPUS TO PROTECT US FROM "TOWNIES"
# THE ONLY DANGER ABOUT AFTER LIGHTS STUDYING | IS BEING REPORTED | BY THE VICTOR OR PINKERTON GUARDS WHO PATROL THE CAMPUS TO PROTECT US FROM " TOWNIES "
# THE VICTOR OR PINKERTON GUARDS WHO PATROL THE CAMPUS TO PROTECT US FROM " TOWNIES " being REPORTED THE ONLY DANGER ABOUT AFTER LIGHTS STUDYING
#
# 86
# The FIRST Global competition (For Inspiration and Recognition of Science and Technlogy) was founded by Dean Kamen to encourage interest in applied science, technology, engineering, and mathematics in young people.
# The FIRST Global competition ( For Inspiration and Recognition of Science and Technlogy ) | was founded | by Dean Kamen
# Dean Kamen founded The FIRST Global competition ( For Inspiration and Recognition of Science and Technlogy ) to encourage interest in applied science , technology , engineering , and mathematics in young people .
#
# 87
# Afghanistan is not one of the nations covered by President Trump's travel ban, but teams from Sudan, Iran, Libya, and Yemen, which are covered, are among the 163 teams in the competition.
# Failed: Afghanistan is not one of the nations covered by President Trump's travel ban, but teams from Sudan, Iran, Libya, and Yemen, which are covered, are among the 163 teams in the competition.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 88
# Syria and all refugees are covered by the ban.
# Syria and all refugees | are covered | by the ban
# the ban covers Syria and all refugees .
#
# 89
# Ahmed Mohamed, a 14-year-old boy from Irving, Texas, was arrested at his school by police after he brought a digital clock he had made to school.
# Ahmed Mohamed , a 14 - year - old boy from Irving , Texas , | was arrested | by police
# police arrested Ahmed Mohamed , a 14 - year - old boy from Irving , Texas , at his school after he brought a digital clock he had made to school .
#
# 90
# Images of the boy wearing a NASA T-shirt and handcuffed by the police were quickly posted and reposted online.
# Failed: Images of the boy wearing a NASA T-shirt and handcuffed by the police were quickly posted and reposted online.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 91
# The accident, which occurred yesterday afternoon, was caused by strong winds and heavy rain that led the crane to fall.
# The accident , which occurred yesterday afternoon , | was caused | by strong winds and heavy rain that led the crane to fall
# strong winds and heavy rain that led the crane to fall caused The accident , which occurred yesterday afternoon , .
#
# 92
# Recent reports have revealed that a defector from the elite group within Scientology called the Sea Org was first persuaded to travel back to a management building for the organization in California, where he was interrogated by an attorney for Scientology and then arrested.
# Failed: Recent reports have revealed that a defector from the elite group within Scientology called the Sea Org was first persuaded to travel back to a management building for the organization in California, where he was interrogated by an attorney for Scientology and then arrested.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 93
# Montalvo was subsequently motivated to seek out information about Scientology on the Internet, and came upon a blog written by Rathbun.
# Failed: Montalvo was subsequently motivated to seek out information about Scientology on the Internet, and came upon a blog written by Rathbun.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 94
# According to Rathbun the Scientology property in question was returned by mail to the organization by Montalvo shortly after he left the Sea Org.
# the Scientology property in question | was returned | by Montalvo
# According to Rathbun Montalvo returned the Scientology property in question by mail to the organization shortly after he left the Sea Org .
#
# 95
# "Daniel was picked up by an investigator in a black car with blacked out windows.
# Daniel | was picked | by an investigator in a black car with blacked out windows
# " an investigator in a black car with blacked out windows picked Daniel up .
#
# 96
# Montalvo has been assisted by former members of Scientology, including musician Tiziano Lugli and actor Jason Beghe.
# Montalvo | has been assisted | by former members of Scientology , including musician Tiziano Lugli and actor Jason Beghe
# former members of Scientology , including musician Tiziano Lugli and actor Jason Beghe have assisted Montalvo .
#
# 97
# Pro-Beijing DAB's Starry Lee and Holden Chow were successfully elected in this constituency, while pro-Beijing veteran politician Wong Kwok-hing of FTU was defeated by 10,694 votes by James To.
# Failed: Pro-Beijing DAB's Starry Lee and Holden Chow were successfully elected in this constituency, while pro-Beijing veteran politician Wong Kwok-hing of FTU was defeated by 10,694 votes by James To.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 98
# Wikinews has learned that according to an Internet posting made just over 24 hours ago, the Church of Scientology's website is being attacked by hackers, causing the site to shut down.
# the Church of Scientology 's website | is being attacked | by hackers
# Wikinews has learned that according to an Internet posting made just over 24 hours ago , hackers being attacked the Church of Scientology 's website , causing the site to shut down .
#
# 99
# The attack was launched on Wednesday by a user labelled "Anonymous", on the website "Insurgency Wiki", a spinoff of 4chan.
# The attack | was launched | by a user labelled " Anonymous " , on the website " Insurgency Wiki " , a spinoff of 4chan
# a user labelled " Anonymous " , on the website " Insurgency Wiki " , a spinoff of 4chan launched The attack on Wednesday .
#
# 100
# The "History" section of the site explains, in a satirical fashion, that the incident was prompted by the Church of Scientology's attempts to remove a promotional video featuring Scientologist Tom Cruise from YouTube.
# the incident | was prompted | by the Church of Scientology 's attempts to remove a promotional video featuring Scientologist Tom Cruise from YouTube
# The " History " section of the site explains , in a satirical fashion , that the Church of Scientology 's attempts to remove a promotional video featuring Scientologist Tom Cruise from YouTube prompted the incident .
#
# 101
# Local public transportation hubs are often swamped by the event.
# Local public transportation hubs | are often swamped | by the event
# the event often swamped Local public transportation hubs .
#
# 102
# A leaked internal letter seen by Sky News says "failure to return the questionnaire without reasonable explanation may result in an individual's asylum claim being withdrawn in line with the published policy", but the government will provide a reminder after the deadline and consider extensions.
# Failed: A leaked internal letter seen by Sky News says "failure to return the questionnaire without reasonable explanation may result in an individual's asylum claim being withdrawn in line with the published policy", but the government will provide a reminder after the deadline and consider extensions.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 103
# A similar fast-track system backed by the British Red Cross in September 2021 for 3,000 Afghan refugees was reportedly rejected by Prime Minister Boris Johnson over fears it would amount to amnesty, which the Home Office today rejects, and strain the UK's welfare and housing systems.
# A similar fast - track system backed by the British Red Cross in September 2021 for 3,000 Afghan refugees | was reportedly rejected | by Prime Minister Boris Johnson
# Prime Minister Boris Johnson reportedly rejected A similar fast - track system backed by the British Red Cross in September 2021 for 3,000 Afghan refugees over fears it would amount to amnesty , which the Home Office today rejects , and strain the UK 's welfare and housing systems .
#
# 104
# Panama's attempt in the 54th minute, by Michael Murillo, was saved by Thibaut Courtois.
# Panama 's attempt in the 54th minute , by Michael Murillo , | was saved | by Thibaut Courtois
# Thibaut Courtois saved Panama 's attempt in the 54th minute , by Michael Murillo , .
#
# 105
# Four minutes later, Tunisia's goalkeeper Mouez Hassen was substituted off due to injury and replaced by Farouk Ben Mustapha.
# Failed: Four minutes later, Tunisia's goalkeeper Mouez Hassen was substituted off due to injury and replaced by Farouk Ben Mustapha.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 106
# Those who were tripped were then crushed by the wave of people behind them.
# Those who were tripped | were then crushed | by the wave of people behind them
# ...
# Concepts | are informed | by our semantic memory
# our semantic memory informs Concepts ( you will learn more about semantic memory in a later chapter ) and are present in every aspect of our lives ; however , one of the easiest places to notice concepts is inside a classroom , where they are discussed explicitly .
#
# 132
# Some concepts, like tolerance, are agreed upon by many people, because they have been used in various ways over many years.
# Some concepts , like tolerance , | are agreed | by many people
# many people agree Some concepts , like tolerance , upon , because they have been used in various ways over many years .
#
# 133
# The innovator’s dilemma was presented by Clayton Christensen to explain disruptive technology, which are technologies that, once introduced, displace established patterns, processes, and systems previously accepted as normal or accepted.
# The innovator ’s dilemma | was presented | by Clayton Christensen
# Clayton Christensen presented The innovator ’s dilemma to explain disruptive technology , which are technologies that , once introduced , displace established patterns , processes , and systems previously accepted as normal or accepted .
#
# 134
# We seem to think moral questions have correct answers; that the correct answers are made correct by objective moral facts; that moral facts are wholly determined by circumstances; and that, by engaging in moral conversation and argument, we can discover what these objective facts are.
# the correct answers | are made | by objective moral facts
# We seem to think moral questions have correct answers ; that objective moral facts make the correct answers correct ; that moral facts are wholly determined by circumstances ; and that , by engaging in moral conversation and argument , we can discover what these objective facts are .
#
# 135
# Street starts with the premise that our moral judgments are influenced by evolutionary forces.
# our moral judgments | are influenced | by evolutionary forces
# Street starts with the premise that evolutionary forces influence our moral judgments .
#
# 136
# Given that our moral beliefs are influenced by evolutionary forces, and not by the moral facts, our moral beliefs would be the same even if the moral facts would change.
# our moral beliefs | are influenced | by evolutionary forces , and not by the moral facts
# Given that evolutionary forces , and not by the moral facts influence our moral beliefs , our moral beliefs would be the same even if the moral facts would change .
#
# 137
# This personality trait was defined as “grit” by the psychologist Angela Duckworth. 1
# This personality trait | was defined | by the psychologist Angela Duckworth
# the psychologist Angela Duckworth defined This personality trait as “ grit ” . 1
#
# 138
# Europe’s colonial expansion, begun in the sixteenth century, was often accompanied by a severe cultural imperialism.
# Europe ’s colonial expansion , begun in the sixteenth century , | was often accompanied | by a severe cultural imperialism
# a severe cultural imperialism often accompanied Europe ’s colonial expansion , begun in the sixteenth century , .
#
# 139
# An exchange student from China might be annoyed by the constant interruptions in class as other students ask questions—a practice that is considered rude in China.
# An exchange student from China | might be annoyed | by the constant interruptions in class as other students ask questions — a practice that is considered rude in China
# Failed: An exchange student from China might be annoyed by the constant interruptions in class as other students ask questions—a practice that is considered rude in China.
# Error: 'NoneType' object is not subscriptable <class 'TypeError'>
#
# 140
# Is light actually bent from its straight-line path by the mass of Earth?
# light | Is actually bent | by the mass of Earth
# Is the mass of Earth actually bent light from its straight - line path ?
#
# 141
# How can light, which has no mass, be affected by gravity?
# light , which has no mass , | How can be affected | by gravity
# How can gravity How can affected light , which has no mass , ?
#
# 142
# Einstein preferred to think that it is space and time that are affected by the presence of a large mass; light beams, and everything else that travels through space and time, then find their paths affected.
# that | are affected | by the presence of a large mass
# Einstein preferred to think that it is space and time the presence of a large mass affects that ; light beams , and everything else that travels through space and time , then find their paths affected .
#
# 143
# I love how they're, like, mesmerized by the pizza.
# they | 're mesmerized | by the pizza
# I love how the pizza mesmerizes them .
#
# 144
# It was discovered in the year of 1925 by a professor called Abraham Perold in the University of Stellenbosch.
# It | was discovered | by a professor called Abraham Perold
# a professor called Abraham Perold discovered It in the year of 1925 in the University of Stellenbosch .
#
# 145
# Despite the common perception that Cleveland is an industrial town, just beyond the automotive and steel plants, a clean and beautiful downtown rises at the mouth of the Cuyahoga River on the southern shore of Lake Erie (often marvelled over by visitors who are surprised you can't see the other side, i.e., Canada).
# Failed: Despite the common perception that Cleveland is an industrial town, just beyond the automotive and steel plants, a clean and beautiful downtown rises at the mouth of the Cuyahoga River on the southern shore of Lake Erie (often marvelled over by visitors who are surprised you can't see the other side, i.e., Canada).
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 146
# Serving as a global model for urban rebirth, Cleveland has been named one of the top 10 international visitor hotspots by Travel and Leisure magazine.
# Cleveland | has been named | by Travel and Leisure magazine
# Serving as a global model for urban rebirth , Travel and Leisure magazine had named Cleveland one of the top 10 international visitor hotspots .
#
# 147
# Fort Lee is bordered by Edgewater, Englewood Cliffs, Cliffside Park and Leonia.
# Fort Lee | is bordered | by Edgewater , Englewood Cliffs , Cliffside Park and Leonia
# Edgewater , Englewood Cliffs , Cliffside Park and Leonia borders Fort Lee .
#
# 148
# Fort Lee can also be accessed by boat or ferry from New York City via Edgewater and Weehawken docks.
# Fort Lee | can also be accessed | by boat or ferry
# boat or ferry can also accessed Fort Lee from New York City via Edgewater and Weehawken docks .
#
# 149
# Old and new meet in Fort Lee, as the Good Shepherd Episcopalian Church is dwarfed by a residential highrise immediately behind it
# the Good Shepherd Episcopalian Church | is dwarfed | by a residential highrise
# Old and new meet in Fort Lee , as a residential highrise dwarfs the Good Shepherd Episcopalian Church immediately behind it
#
# 150
# The George Washington Bridge can be crossed by bicycle or on foot as well as in a motorized vehicle.
# The George Washington Bridge | can be crossed | by bicycle or on foot as well as in a motorized vehicle
# bicycle or on foot as well as in a motorized vehicle can crossed The George Washington Bridge .
#
# 151
# Some are within 5 – 10 minutes walking distance from the nearest parking lot, some require at least 3 – 4 hours of hiking (those are, of course less frequented by other tourists and you might find yourself alone at a spectacular waterfall in the middle of nowhere - an amazing experience!).
# those | are less frequented | by other tourists
# Some are within 5 – 10 minutes walking distance from the nearest parking lot , some require at least 3 – 4 hours of hiking ( other tourists less frequented those and you might find yourself alone at a spectacular waterfall in the middle of nowhere - an amazing experience ! ) .
#
# 152
# The square is surrounded by buildings from the Safavid era.
# The square | is surrounded | by buildings from the Safavid era
# buildings from the Safavid era surround The square .
#
# 153
# The rapid development of Łódź in the second half of the 19th century was brought about by the rise of enormous industrialist fortunes.
# The rapid development of Łódź in the second half of the 19th century | was brought | by the rise of enormous industrialist fortunes
# the rise of enormous industrialist fortunes brought The rapid development of Łódź in the second half of the 19th century about .
#
# 154
# The day before the outbreak of World War II, Łódź was inhabited by approximately 672,000 people, among whom 35% were of Jewish faith and some 15% were ethnic German.
# Łódź | was inhabited | by approximately 672,000 people , among whom 35 % were of Jewish faith and some 15 % were ethnic German
# The day before the outbreak of World War II , approximately 672,000 people , among whom 35 % were of Jewish faith and some 15 % were ethnic German inhabited Łódź .
#
# 155
# Although the city was not destroyed in the aftermath, the material losses were serious as the machinery, raw materials and finished goods were taken away by the fleeing Nazis.
# Failed: Although the city was not destroyed in the aftermath, the material losses were serious as the machinery, raw materials and finished goods were taken away by the fleeing Nazis.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 156
# The city was founded by the Spanish conquistadors in the 1540s on top of a centuries-old Maya city called T'ho.
# The city | was founded | by the Spanish conquistadors in the 1540s
# the Spanish conquistadors in the 1540s founded The city on top of a centuries - old Maya city called T'ho .
#
# 157
# The Salt and Verde Rivers of central Arizona were exploited for large-scale agriculture by Native Americans as early as the 11th century.
# The Salt and Verde Rivers of central Arizona | were exploited | by Native Americans
# Native Americans exploited The Salt and Verde Rivers of central Arizona for large - scale agriculture as early as the 11th century .
#
# 158
# Although the region is small, it is characterized by unique land and marine biodiversity.
# it | is characterized | by unique land and marine biodiversity
# Although the region is small , unique land and marine biodiversity characterizes it .
#
# 159
# The interior of the island is dominated by the beautiful and green Hagghier mountains and limestone plateau.
# The interior of the island | is dominated | by the beautiful and green Hagghier mountains and limestone plateau
# the beautiful and green Hagghier mountains and limestone plateau dominate The interior of the island .
#
# 160
# The islands were formed during the last ice age, by ice sliding over the area from the south, only the ancient hilltops was spared from submersion, and forms the many islands and islets peaking above the sea everywhere.
# The islands | were formed | , by ice sliding over the area from the south , only the ancient hilltops was spared from submersion , and forms the many islands and islets peaking above the sea everywhere
# , ice sliding over the area from the south , only the ancient hilltops was spared from submersion , and forms the many islands and islets peaking above the sea everywhere formed The islands during the last ice age .
#
# 161
# The main entry points are Svendborg which is easily reach both by highway, bus and train - and Faaborg, which is best reached by bus from Odense.
# which | is easily reach | both by highway , bus and train
# The main entry points are Svendborg both highway , bus and train easily reach which - and Faaborg , which is best reached by bus from Odense .
#
# 162
# While some islands are connected by the same ferry, you will generally have to go back to the mainland to pass between the islands, if you rely on public transportation.
# some islands | are connected | by the same ferry
# While the same ferry connects some islands , you will generally have to go back to the mainland to pass between the islands , if you rely on public transportation .
#
# 163
# For the remainder of the year, short stays are permitted, which is interpreted by the authorities as a day or a night.
# Failed: For the remainder of the year, short stays are permitted, which is interpreted by the authorities as a day or a night.
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 164
# shorts are primarily worn by laborers and schoolchildren.
# shorts | are primarily worn | by laborers and schoolchildren
# laborers and schoolchildren primarily worn shorts .
#
# 165
# Monks will sometimes be aided by a layman who will accept things from women merit-makers on their behalf.
# Monks | will sometimes be aided | by a layman who will accept things from women merit - makers on their behalf
# a layman who will accept things from women merit - makers on their behalf will sometimes aided Monks .
#
# 166
# Tulsa has one of the largest concentrations of Art Deco in the nation, having been a booming city during the 1920s when the architecture was first built by rich oil barons who built stately mansions and turned the Downtown area into a treasure trove of art.
# the architecture | when was first built | by rich oil barons who built stately mansions and turned the Downtown area into a treasure trove of art
# Tulsa has one of the largest concentrations of Art Deco in the nation , having been a booming city during the 1920s when rich oil barons who built stately mansions and turned the Downtown area into a treasure trove of art when first built the architecture .
#
# 167
# North / South is divided by Admiral Blvd.
# North / South | is divided | by Admiral Blvd
# Admiral Blvd divides North / South .
#
# 168
# York was known as Eboracum by the Romans, who founded the fortress city on the River Ouse in the year 71.
# York | was known | by the Romans , who founded the fortress city on the River Ouse in the year 71
# the Romans , who founded the fortress city on the River Ouse in the year 71 knew York as Eboracum .
#
# 169
# When they are cruel, their friends will usually ignore it or not do anything to stop it since they're afraid that they'll be treated badly by their 'friend.'
# they | 'll be treated | by their ' friend . '
# When they are cruel , their friends will usually ignore it or not do anything to stop it since they 're afraid that their ' friend . ' will treated them badly
#
# 170
# Basil needs warm air and sun to do well, so it's often easiest to start the seeds indoors instead of risking that they'll get damaged by frost.
# they | 'll get damaged | by frost
# Basil needs warm air and sun to do well , so it 's often easiest to start the seeds indoors instead of risking that frost will damaged them .
#
# 171
# Your reserve chute should have been packed by a certified rigger and is moderately less likely to fail; therefore, it may be helpful to focus your efforts on opening your reserve parachute.
# Your reserve chute | should have been packed | by a certified rigger
# Failed: Your reserve chute should have been packed by a certified rigger and is moderately less likely to fail; therefore, it may be helpful to focus your efforts on opening your reserve parachute.
# Error: 'NoneType' object is not subscriptable <class 'TypeError'>
#
# 172
# There are many different ways of playing Quidditch, but the most commonly used set of rules are those given by the International Quidditch Association (which can be found here).
# Failed: There are many different ways of playing Quidditch, but the most commonly used set of rules are those given by the International Quidditch Association (which can be found here).
# Error: 'NoneType' object has no attribute 'text' <class 'AttributeError'>
#
# 173
# Alternatively the snitch can be a small yellow ball (tennis balls work great) that is hidden before the game starts by a bystander or referee.
# that | is hidden | by a bystander or referee
# Alternatively the snitch can be a small yellow ball ( tennis balls work great ) a bystander or referee hides that before the game starts .

# %%
passive_sentences_test[69].text
# Out:
# "I dreamed that I was at the offworlder's home, where it was summer but no one was taking care of the stabros, and they were all glad, and so I was a hero - and I was startled awake by gunfire."

# %%
passive_sentences_test[69].depassivize().text
# Out:
# "I dreamed that I was at the offworlder 's home , where it was summer but no one was taking care of the stabros , and they were all glad , and so I was a hero - and gunfire startled me awake ."
