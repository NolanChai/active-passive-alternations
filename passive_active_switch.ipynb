# %%
import conllu
from conllu import Token, parse, parse_tree
from pyinflect import getAllInflections, getInflection
from src.utils import *
from src.units.word import Word

# %%
with open("data/en_gum-ud-train.conllu", "r") as f:
    text = f.read()
sentences = parse(text)

# %%
token = sentences[20][4]
[w for w in sentences[20]]
# Out:
# [{'id': 1,
#   'form': 'The',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 2,
#   'deprel': 'det',
#   'deps': [('det', 2)],
#   'misc': {'Discourse': 'elaboration-additional:39->36:2:sem-synym-369-370,380-386,391,401-402-_',
#    'Entity': '(95-abstract-new-nnnnn-cf7-2-sgl',
#    'PDTB': 'Implicit:Expansion.Level-of-detail.Arg2-as-detail:in particular:_:364-387:388-423'}},
#  {'id': 2,
#   'form': 'direction',
#   'lemma': 'direction',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nsubj:pass',
#   'deps': [('nsubj:pass', 6)],
#   'misc': {'MSeg': 'direct-ion'}},
#  {'id': 3,
#   'form': 'of',
#   'lemma': 'of',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 4,
#   'deprel': 'case',
#   'deps': [('case', 4)],
#   'misc': None},
#  {'id': 4,
#   'form': 'saccades',
#   'lemma': 'saccade',
#   'upos': 'NOUN',
#   'xpos': 'NNS',
#   'feats': {'Number': 'Plur'},
#   'head': 2,
#   'deprel': 'nmod',
#   'deps': [('nmod:of', 2)],
#   'misc': {'Entity': '(93-event-giv:act-nnnnn-cf2-1-coref)95)',
#    'MSeg': 'saccade-s'}},
#  {'id': 5,
#   'form': 'is',
#   'lemma': 'be',
#   'upos': 'AUX',
#   'xpos': 'VBZ',
#   'feats': {'Mood': 'Ind',
#    'Number': 'Sing',
#    'Person': '3',
#    'Tense': 'Pres',
#    'VerbForm': 'Fin'},
#   'head': 6,
#   'deprel': 'aux:pass',
#   'deps': [('aux:pass', 6)],
#   'misc': None},
#  {'id': 6,
#   'form': 'determined',
#   'lemma': 'determine',
#   'upos': 'VERB',
#   'xpos': 'VBN',
#   'feats': {'Tense': 'Past', 'VerbForm': 'Part', 'Voice': 'Pass'},
#   'head': 0,
#   'deprel': 'root',
#   'deps': [('root', 0)],
#   'misc': {'MSeg': 'determin-ed'}},
#  {'id': 7,
#   'form': 'by',
#   'lemma': 'by',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 9,
#   'deprel': 'case',
#   'deps': [('case', 9)],
#   'misc': None},
#  {'id': 8,
#   'form': 'an',
#   'lemma': 'a',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Ind', 'PronType': 'Art'},
#   'head': 9,
#   'deprel': 'det',
#   'deps': [('det', 9)],
#   'misc': {'Entity': '(85-abstract-giv:inact-nnnnn-cf3-2-coref'}},
#  {'id': 9,
#   'form': 'interaction',
#   'lemma': 'interaction',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'obl:agent',
#   'deps': [('obl:agent', 6)],
#   'misc': {'MSeg': 'inter-act-ion'}},
#  {'id': 10,
#   'form': 'between',
#   'lemma': 'between',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 12,
#   'deprel': 'case',
#   'deps': [('case', 12)],
#   'misc': {'MSeg': 'be-tween'}},
#  {'id': 11,
#   'form': 'the',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 12,
#   'deprel': 'det',
#   'deps': [('det', 12)],
#   'misc': {'Entity': '(96-abstract-new-nnnnn-cf8-2-sgl'}},
#  {'id': 12,
#   'form': 'goals',
#   'lemma': 'goal',
#   'upos': 'NOUN',
#   'xpos': 'NNS',
#   'feats': {'Number': 'Plur'},
#   'head': 9,
#   'deprel': 'nmod',
#   'deps': [('nmod:between', 9)],
#   'misc': {'MSeg': 'goal-s'}},
#  {'id': 13,
#   'form': 'of',
#   'lemma': 'of',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 15,
#   'deprel': 'case',
#   'deps': [('case', 15)],
#   'misc': None},
#  {'id': 14,
#   'form': 'the',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 15,
#   'deprel': 'det',
#   'deps': [('det', 15)],
#   'misc': {'Entity': '(89-person-giv:act-nnnnn-cf1*-2-coref'}},
#  {'id': 15,
#   'form': 'observer',
#   'lemma': 'observer',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'nmod',
#   'deps': [('nmod:of', 12)],
#   'misc': {'Entity': '89)96)', 'MSeg': 'observ-er'}},
#  {'id': 16,
#   'form': 'and',
#   'lemma': 'and',
#   'upos': 'CCONJ',
#   'xpos': 'CC',
#   'feats': None,
#   'head': 19,
#   'deprel': 'cc',
#   'deps': [('cc', 19)],
#   'misc': None},
#  {'id': 17,
#   'form': 'the',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 19,
#   'deprel': 'det',
#   'deps': [('det', 19)],
#   'misc': {'Entity': '(97-abstract-new-nnnnn-cf9-3-coref'}},
#  {'id': 18,
#   'form': 'physical',
#   'lemma': 'physical',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': {'Degree': 'Pos'},
#   'head': 19,
#   'deprel': 'amod',
#   'deps': [('amod', 19)],
#   'misc': {'MSeg': 'physic-al'}},
#  {'id': 19,
#   'form': 'properties',
#   'lemma': 'property',
#   'upos': 'NOUN',
#   'xpos': 'NNS',
#   'feats': {'Number': 'Plur'},
#   'head': 12,
#   'deprel': 'conj',
#   'deps': [('nmod:between', 9), ('conj:and', 12)],
#   'misc': {'MSeg': 'proper-tie-s'}},
#  {'id': 20,
#   'form': 'of',
#   'lemma': 'of',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 23,
#   'deprel': 'case',
#   'deps': [('case', 23)],
#   'misc': None},
#  {'id': 21,
#   'form': 'the',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 23,
#   'deprel': 'det',
#   'deps': [('det', 23)],
#   'misc': {'Entity': '(98-abstract-new-nnnnn-cf10-3-sgl'}},
#  {'id': 22,
#   'form': 'different',
#   'lemma': 'different',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': {'Degree': 'Pos'},
#   'head': 23,
#   'deprel': 'amod',
#   'deps': [('amod', 23)],
#   'misc': {'MSeg': 'differ-ent'}},
#  {'id': 23,
#   'form': 'elements',
#   'lemma': 'element',
#   'upos': 'NOUN',
#   'xpos': 'NNS',
#   'feats': {'Number': 'Plur'},
#   'head': 19,
#   'deprel': 'nmod',
#   'deps': [('nmod:of', 19)],
#   'misc': {'MSeg': 'element-s'}},
#  {'id': 24,
#   'form': 'of',
#   'lemma': 'of',
#   'upos': 'ADP',
#   'xpos': 'IN',
#   'feats': None,
#   'head': 26,
#   'deprel': 'case',
#   'deps': [('case', 26)],
#   'misc': None},
#  {'id': 25,
#   'form': 'the',
#   'lemma': 'the',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': {'Definite': 'Def', 'PronType': 'Art'},
#   'head': 26,
#   'deprel': 'det',
#   'deps': [('det', 26)],
#   'misc': {'Entity': '(99-abstract-new-nnnnn-cf11-2-sgl'}},
#  {'id': 26,
#   'form': 'scene',
#   'lemma': 'scene',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 23,
#   'deprel': 'nmod',
#   'deps': [('nmod:of', 23)],
#   'misc': {'Entity': '99)98)97)85)'}},
#  {'id': 27,
#   'form': '(',
#   'lemma': '(',
#   'upos': 'PUNCT',
#   'xpos': '-LRB-',
#   'feats': None,
#   'head': 29,
#   'deprel': 'punct',
#   'deps': [('punct', 29)],
#   'misc': {'Discourse': 'elaboration-additional:40->39:0:sem-mrnym-404-413,416-_+sem-lxchn-405-406,423-_+grf-prn-414,422-_+lex-indwd-415-_',
#    'SpaceAfter': 'No'}},
#  {'id': 28,
#   'form': 'e.g.',
#   'lemma': 'e.g.',
#   'upos': 'ADV',
#   'xpos': 'FW',
#   'feats': {'Abbr': 'Yes'},
#   'head': 29,
#   'deprel': 'advmod',
#   'deps': [('advmod', 29)],
#   'misc': None},
#  {'id': 29,
#   'form': 'colour',
#   'lemma': 'colour',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 19,
#   'deprel': 'appos',
#   'deps': [('appos', 19)],
#   'misc': {'Bridge': '97<100',
#    'Entity': '(100-abstract-acc:inf-nnnnn-cf4-1-sgl)',
#    'SpaceAfter': 'No'}},
#  {'id': 30,
#   'form': ',',
#   'lemma': ',',
#   'upos': 'PUNCT',
#   'xpos': ',',
#   'feats': None,
#   'head': 31,
#   'deprel': 'punct',
#   'deps': [('punct', 31)],
#   'misc': None},
#  {'id': 31,
#   'form': 'texture',
#   'lemma': 'texture',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 29,
#   'deprel': 'conj',
#   'deps': [('appos', 19), ('conj', 29)],
#   'misc': {'Bridge': '97<101',
#    'Entity': '(101-abstract-acc:inf-nnnnn-cf5-1-sgl)',
#    'SpaceAfter': 'No'}},
#  {'id': 32,
#   'form': ',',
#   'lemma': ',',
#   'upos': 'PUNCT',
#   'xpos': ',',
#   'feats': None,
#   'head': 33,
#   'deprel': 'punct',
#   'deps': [('punct', 33)],
#   'misc': None},
#  {'id': 33,
#   'form': 'brightness',
#   'lemma': 'brightness',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': {'Number': 'Sing'},
#   'head': 29,
#   'deprel': 'conj',
#   'deps': [('appos', 19), ('conj', 29)],
#   'misc': {'Bridge': '97<102',
#    'Entity': '(102-abstract-acc:inf-nnnnn-cf6-1-sgl)',
#    'MSeg': 'bright-ness'}},
#  {'id': 34,
#   'form': 'etc',
#   'lemma': 'etc.',
#   'upos': 'NOUN',
#   'xpos': 'FW',
#   'feats': {'Number': 'Plur', 'Typo': 'Yes'},
#   'head': 29,
#   'deprel': 'conj',
#   'deps': [('appos', 19), ('conj', 29)],
#   'misc': {'CorrectForm': 'etc.',
#    'SpaceAfter': 'No',
#    'XML': '<sic ana:::"etc."></sic>'}},
#  {'id': 35,
#   'form': ')',
#   'lemma': ')',
#   'upos': 'PUNCT',
#   'xpos': '-RRB-',
#   'feats': None,
#   'head': 29,
#   'deprel': 'punct',
#   'deps': [('punct', 29)],
#   'misc': {'SpaceAfter': 'No'}},
#  {'id': 36,
#   'form': '.',
#   'lemma': '.',
#   'upos': 'PUNCT',
#   'xpos': '.',
#   'feats': None,
#   'head': 6,
#   'deprel': 'punct',
#   'deps': [('punct', 6)],
#   'misc': None}]

# %%
Word(token)
# Out:
# {'id': 5,
#  'form': 'is',
#  'lemma': 'be',
#  'upos': 'AUX',
#  'xpos': 'VBZ',
#  'feats': {'Mood': 'Ind',
#   'Number': 'Sing',
#   'Person': '3',
#   'Tense': 'Pres',
#   'VerbForm': 'Fin'},
#  'head': 6,
#  'deprel': 'aux:pass',
#  'deps': [('aux:pass', 6)],
#  'misc': None,
#  'inflection': 'VBZ',
#  'children': []}
