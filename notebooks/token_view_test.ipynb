# %%
import pandas as pd
df = pd.read_csv("/Users/nolan/Documents/Data/UID/sweep_tok_document.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                       doc_id  sent_idx   context uid_level  \
# 0           0  f::GUM_academic_art::-1::og         0  document   (-0,+0)
# 1           1  f::GUM_academic_art::-1::og         1  document   (-0,+0)
# 2           2  f::GUM_academic_art::-1::og         2  document   (-0,+0)
# 3           3  f::GUM_academic_art::-1::og         3  document   (-0,+0)
# 4           4  f::GUM_academic_art::-1::og         4  document   (-0,+0)
#
#   uid_unit                                           sentence  \
# 0    token            Aesthetic Appreciation and Spanish Art:
# 1    token                         Insights from Eye-Tracking
# 2    token  Claire Bailey-Ross claire.bailey-ross@port.ac....
# 3    token  Andrew Beresford a.m.beresford@durham.ac.uk Du...
# 4    token  Daniel Smith daniel.smith2@durham.ac.uk Durham...
#
#                                               tokens  \
# 0  ['A', 'esthetic', 'ĠApp', 'reciation', 'Ġand',...
# ...
