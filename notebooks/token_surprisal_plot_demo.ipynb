# %% [markdown]
# # Token to Surprisal Plot Demo
#
# Demo of `plot_token_surprisal` from `src.utils`.

# %%
import sys
from pathlib import Path

REPO_ROOT = Path.cwd().resolve()
if not (REPO_ROOT / 'src').exists():
    REPO_ROOT = REPO_ROOT.parent
print(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT))
# Out:
# /Users/nolan/Documents/GitHub/active-passive-alternations

# %%
from src.utils import plot_token_surprisal

# %%
tokens = ['Moments', 'like', 'that', 'must', 'make', 'you', 'realize']
surprisals = [3.2, 2.6, 2.9, 4.4, 2.8, 2.3, 5.1]
plot_token_surprisal(tokens, surprisals, title='Example: token surprisal trace')
# Out:
# (<Figure size 1200x400 with 1 Axes>,
#  <Axes: title={'center': 'Example: token surprisal trace'}, xlabel='Token', ylabel='Surprisal (bits)'>)

# %%
save_path = REPO_ROOT / 'plots' / 'token_surprisal_demo.png'
plot_token_surprisal(tokens, surprisals, title='Saved copy', show=False, save_path=save_path)
save_path
# Out:
# PosixPath('/Users/nolan/Documents/GitHub/active-passive-alternations/plots/token_surprisal_demo.png')
